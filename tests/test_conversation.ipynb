# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT))

# %%
from ai.speech.stt import SpeechToText
from ai.speech.tts import TextToSpeech
from ai.llm.model import GermanChatbot

from IPython.display import Audio, display

# %%
stt = SpeechToText("small")
tts = TextToSpeech()
chatbot = GermanChatbot()

print("All AI components loaded!")
# Out:
# All AI components loaded!

# %%
def run_pipeline(audio_path: str):

    # -------------------------
    # 1. Speech → Text
    # -------------------------
    print(" Transcribing...")

    user_text = stt.transcribe(audio_path)

    print("\n You:")
    print(user_text)

    # -------------------------
    # 2. Text → LLM
    # -------------------------
    print("\n Thinking...")

    messages = [
        {
            "role": "user",
            "content": user_text
        }
    ]

    ai_response = chatbot.generate_response(messages)

    print("\n Tutor:")
    print(ai_response)

    # -------------------------
    # 3. Text → Speech
    # -------------------------
    print("\n Generating speech...")

    audio_output = tts.synthesize(
        ai_response,
    )

    print("\n Pipeline complete!")

    return {
        "user_text": user_text,
        "ai_response": ai_response,
        "audio_path": audio_output,
    }

# %%
result = run_pipeline(
    "../audio/input/german_test.mp3"
)
# Out:
#  Transcribing...
#
#  You:
# Part 1 – Asking about the weather Wie ist die Temperatur? Wie warm ist es? Was hat der Wetterbericht heute Morgen vorhergesagt? Part 2 – Describing the weather Es sind 30°C draußen. Sei vorsichtig, es ist rutschig. Es ist heute so bewölkt. Es ist ein stürmischer Tag. Wir bekommen endlich etwas Schnee. Es schüttet wie aus Eimern. Part 3 – Describing feelings towards the weather Mir ist zu kalt. Ich mag es nicht, wenn es zu heiß ist. Mir ist jetzt richtig warm. Ich bin ein kaltwetter Mensch.
#
#  Thinking...
#
#  Tutor:
# Hey! 😊 Deine Fragen zum Wetter sind gut! Aber zwei kleine Hinweise:
#
# 1. „Es sind 30°C draußen“ → „Es **ist** 30°C draußen“ (bei Temperaturen immer *ist*).
# 2. „Ich bin ein kaltwetter Mensch“ → Vielleicht *„Ich mag kaltwetter“* oder *„Ich bin ein Kälte-Begeisterter“*.
#
# Was hat der Wetterbericht heute Morgen vorausgesagt? 😄
#
#  Generating speech...
#
#  Pipeline complete!

# %%
conversation_history = []

# %%
def run_pipeline(audio_path: str, conversation_history: list):

    # -------------------------
    # 1. Speech → Text
    # -------------------------
    print(" Transcribing...")

    user_text = stt.transcribe(audio_path)

    print("\n You:")
    print(user_text)

    # Add user message in history
    conversation_history.append({
        "role": "user",
        "content": user_text
    })

    # -------------------------
    # 2. Text → LLM
    # -------------------------
    print("\n Thinking...")

    ai_response = chatbot.generate_response(conversation_history)

    print("\n Tutor:")
    print(ai_response)

    # Add AI response
    conversation_history.append({
        "role": "assistant",
        "content": ai_response
    })
    # -------------------------
    # 3. Text → Speech
    # -------------------------
    print("\n Generating speech...")

    audio_output = tts.synthesize(
        ai_response,
    )

    print("\n Pipeline complete!")

    return {
        "user_text": user_text,
        "ai_response": ai_response,
        "audio_path": audio_output,
    }

# %%
result = run_pipeline(
    "../audio/input/german_test.mp3",
    conversation_history
)
# Out:
#  Transcribing...
#
#  You:
# Part 1 – Asking about the weather Wie ist die Temperatur? Wie warm ist es? Was hat der Wetterbericht heute Morgen vorhergesagt? Part 2 – Describing the weather Es sind 30°C draußen. Sei vorsichtig, es ist rutschig. Es ist heute so bewölkt. Es ist ein stürmischer Tag. Wir bekommen endlich etwas Schnee. Es schüttet wie aus Eimern. Part 3 – Describing feelings towards the weather Mir ist zu kalt. Ich mag es nicht, wenn es zu heiß ist. Mir ist jetzt richtig warm. Ich bin ein kaltwetter Mensch.
#
#  Thinking...
#
#  Tutor:
# Hallo! 😊
#
# Deine Fragen zu Teil 1 sind sehr gut formuliert! 👍
#
# In Teil 2: "Es sind 30°C draußen" → "Es **ist** 30°C draußen" (Temperatur wird mit *es ist* gesagt). 😊
#
# In Teil 3: "Ich bin ein kaltwetter Mensch" → *kaltwetter* ist kein Standardwort. Vielleicht meinst du: *"Ich mag kaltes Wetter"* oder *"Ich bin ein Mensch, der kaltes Wetter mag"*? 😄
#
# Was hat der Wetterbericht heute Morgen vorhergesagt? 😊
#
# Viel Erfolg beim Lernen! 🌟
#
#  Generating speech...
#
#  Pipeline complete!

# %%
for _ in conversation_history:
    print(_)
# Out:
# {'role': 'user', 'content': 'Part 1 – Asking about the weather Wie ist die Temperatur? Wie warm ist es? Was hat der Wetterbericht heute Morgen vorhergesagt? Part 2 – Describing the weather Es sind 30°C draußen. Sei vorsichtig, es ist rutschig. Es ist heute so bewölkt. Es ist ein stürmischer Tag. Wir bekommen endlich etwas Schnee. Es schüttet wie aus Eimern. Part 3 – Describing feelings towards the weather Mir ist zu kalt. Ich mag es nicht, wenn es zu heiß ist. Mir ist jetzt richtig warm. Ich bin ein kaltwetter Mensch.'}
# {'role': 'assistant', 'content': 'Hallo! 😊  \n\nDeine Fragen zu Teil 1 sind sehr gut formuliert! 👍  \n\nIn Teil 2: "Es sind 30°C draußen" → "Es **ist** 30°C draußen" (Temperatur wird mit *es ist* gesagt). 😊  \n\nIn Teil 3: "Ich bin ein kaltwetter Mensch" → *kaltwetter* ist kein Standardwort. Vielleicht meinst du: *"Ich mag kaltes Wetter"* oder *"Ich bin ein Mensch, der kaltes Wetter mag"*? 😄  \n\nWas hat der Wetterbericht heute Morgen vorhergesagt? 😊  \n\nViel Erfolg beim Lernen! 🌟'}

# %%
from IPython.display import Audio, display

display(
    Audio(
        result["audio_path"],
        autoplay=False
    )
)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
from services.conversation_service import ConversationService

# %%
service = ConversationService()

conversation_history = []
# Out:
# Loading AI models...
# All AI models loaded.

# %%
result = service.process_audio(
    "../audio/input/test_aud.mp4",
    conversation_history,
)
print("User:")
print(result["user_text"])

print("\nAI:")
print(result["ai_response"])

print("\nAudio:")
print(result["audio_path"])
# Out:
# User:
# Hallo, ich heiße Witya und ich bin 19 Jahre alt. Ich komme aus Nepal, aber jetzt wohne ich in Neu-Delli. Meine Hobbys sind Musikkoren und Deutschlandern. Ich möchte nach Deutschland gehen, um Ausbildung zu machen.
#
# AI:
# Hallo Witya! 😊 Danke für deine Nachricht. Du bist 19 und kommst aus Nepal – das ist super! Du wohnst aktuell in Neu-Delhi? (Hinweis: In Deutsch schreibt man *Neu-Delhi*, nicht *Neu-Delli*.) Deine Hobbys: *Musikkoren* und *Deutschlandern* – vielleicht meinst du *Musik* und *Deutsch lernen*? 😊 Das klingt toll, dass du nach Deutschland gehen möchtest, um Ausbildung zu machen! Welche Ausbildung interessiert dich am meisten? Ich helfe dir gerne dabei!
#
# Audio:
# C:\Users\ACER\Desktop\AI-tutor\audio\output\response_11c433b9ab9a4e8c9eb2157ec4e4393c.wav
