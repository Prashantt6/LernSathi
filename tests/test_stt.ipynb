# %%
import torch

print("PyTorch:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())

if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))
# Out:
# PyTorch: 2.11.0+cu128
# CUDA available: True
# GPU: NVIDIA GeForce RTX 3050 Laptop GPU

# %%
import whisper

device = "cuda" if torch.cuda.is_available() else "cpu"

print("Using device:", device)

model= whisper.load_model("small", device=device)

print("Whisper is loaded")
# Out:
# Using device: cuda
# 100%|███████████████████████████████████████| 461M/461M [01:32<00:00, 5.26MiB/s]
# Whisper is loaded

# %%
audio_path = "../audio/input/german_test.mp3"

result = model.transcribe(
    audio_path,
    language="de"
)

print(result["text"])
# Out:
#  Part 1 – Asking about the weather Wie ist die Temperatur? Wie warm ist es? Was hat der Wetterbericht heute Morgen vorhergesagt? Part 2 – Describing the weather Es sind 30°C draußen. Sei vorsichtig, es ist rutschig. Es ist heute so bewölkt. Es ist ein stürmischer Tag. Wir bekommen endlich etwas Schnee. Es schüttet wie aus Eimern. Part 3 – Describing feelings towards the weather Mir ist zu kalt. Ich mag es nicht, wenn es zu heiß ist. Mir ist jetzt richtig warm. Ich bin ein kaltwetter Mensch.
